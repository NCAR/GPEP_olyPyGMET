# %%
import numpy as np
from matplotlib import pyplot as plt
file0='/Users/localuser/Research/EMDNA/stndata_whole.npz'
file1='/Users/localuser/Downloads/rea_pop_198706.npz'
file2='/Users/localuser/Downloads/bmamerge_pop_198706.npz'
d1=np.load(file1)
d2=np.load(file2)
reapop_grid=d1['reapop_grid']
bma_data=d2['bma_data']
bma_error=d2['bma_error']

# %%
np.shape(reapop_grid)
# Out:
# (3, 800, 1300, 30)

# %%
plt.imshow(reapop_grid[1,:,:,9])
plt.colorbar()

# %%
import numpy as np
from matplotlib import pyplot as plt
file0='/Users/localuser/Research/EMDNA/stndata_whole.npz'
file1='/Users/localuser/Research/EMDNA/regression/weight_nearstn.npz'
file2='/Users/localuser/Research/EMDNA/regression/weight_nearstn-old.npz'
d1=np.load(file1)
d2=np.load(file2)
near_loc_stn1 = d1['near_stn_prcpLoc']
near_loc_stn2 = d2['near_stn_prcpLoc']
near_weight_stn1 = d1['near_stn_prcpWeight']
near_weight_stn2 = d2['near_stn_prcpWeight']

# %%
np.where(near_loc_stn1[:,0]!=near_loc_stn2[:,0])
# Out:
# (array([   47,    75,    83,   143,   169,   467,   514,   526,   527,
#           556,   561,   565,   581,   585,   609,  1489,  1511,  1516,
#          1581,  1582,  1682,  1845,  1930,  1932,  1989,  2000,  2053,
#          2056,  2059,  2070,  2521,  2600,  2722,  2813,  2816,  2858,
#          2872,  3038,  3431,  3467,  3592,  4040,  4153,  4633,  4634,
#          4637,  5326,  5878,  6424,  6447,  6956,  7801,  7988,  8024,
#          8577,  9427, 10581, 10730, 10901, 11495, 11957, 11982, 12059,
#         12075, 12281, 12338, 12890, 12911, 12929, 13051, 13479, 13567,
#         14296, 14301, 14323, 14325, 14397, 14398, 14460, 14826, 15022,
#         15047, 15459, 15715, 15971, 16706, 17207, 17336, 17625, 18081,
#         18177, 18933, 18948, 18960, 19002, 19019, 19041, 19070, 19391,
#         19462, 19521, 19750, 19848, 19849, 22086, 22087, 22258, 22584,
#         22619, 23246, 23277, 23286, 23287, 23294, 23295, 23388, 23471,
#         23472, 23483, 23487, 23511, 23516, 23520, 23521, 23527, 23584,
#         23601, 23604, 23623, 23675, 23725, 23731, 23756, 23757, 23784,
#         23793, 23807, 23820, 23843, 23878, 23928, 23981, 24054, 24057,
#         24058, 24113, 24122, 24124, 24146, 24168, 24187, 24198, 24206,
#         24218, 24225, 24229, 24240, 24269, 24274, 24282, 24283, 24287,
#         24296, 24298, 24299, 24303, 24313, 24352, 24540, 24847, 24848,
#         24855, 24856, 24875, 24880, 24881, 24892, 24893, 24908, 24915,
#         24951, 24964, 25104, 25152, 25154, 25182, 25217, 25235, 25236,
#         25237, 25245, 25256, 25266, 25267, 25408, 25507, 25566, 25584,
#         25616, 25617, 25622, 25650, 25691, 25703, 25704, 25708, 25712,
#         25812, 25823, 25912, 25971, 26052, 26064, 26090, 26115, 26189,
#         26197, 26218, 26238, 26246, 26247, 26250, 26272, 26307, 26379,
#         26492, 26527, 26558, 26574, 26576, 26586, 26588, 26606, 26607,
#         26628, 26631, 26644, 26650, 26681, 26684, 26732, 26733, 26734,
#         26735, 26736, 26738, 26741, 26743, 26744, 26745, 26746, 26747,
#         26748, 26749, 26750, 26752, 26755, 26757, 26759, 26760, 26761,
#         26762, 26763, 26764, 26765, 26766, 26767, 26768, 27139, 27142,
#         27183, 27269]),)

# %%
print(near_loc_stn1[10730])
print(near_loc_stn2[10730])
# Out:
# [10725  6790  6787 10740 26864 22973  6792  6795  6841 14576 24699 22482
#   6791  6837  6789  6796  6788  6840  6838 22875 26407  6794 22500 10804
#  24697  6793  6839 14620  8927  8925]
# [26765 10725  6790  6787 10740 26864 22973  6792  6795  6841 14576 24699
#  22482  6791  6837  6789  6796  6788  6840  6838 22875 26407  6794 22500
#  10804 24697  6793  6839 14620  8927]

# %%
len(np.unique(near_loc_stn2))
# Out:
# 24717

# %%
file='/Users/localuser/Research/EMDNA/regression/output_20071101-20071130.npz'
d=np.load(file)
pop=d['pop']
pop=np.flipud(pop)

# %%
plt.imshow(pop[:,:,10])
