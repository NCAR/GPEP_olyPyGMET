# %%
# evaluate downscaled, corrected and merged reanalysis
import numpy as np
import auxiliary as au
from matplotlib import pyplot as plt

file1='/Users/localuser/Downloads/stndata_whole.npz'
file2='/Users/localuser/Research/Test/ERA5_downto_stn.npz'
file3='/Users/localuser/Research/Test/mergecorr_prcp_BMA.npz'
d1=np.load(file1)
d2=np.load(file2)
d3=np.load(file3)
stn_lle=d1['stn_lle']
stndata=d1['prcp_stn']
readata_down=d2['prcp_readown']
readata_corr=d3['reacorr_stn']
readata_merge=d3['reamerge_stn']
nstn,ntimes=np.shape(stndata)
met_prcp=np.zeros([5,nstn,4])
for i in range(nstn):
    met_prcp[0,i,:] = au.metric(stndata[i],readata_down[i])
    for r in range(3):
        met_prcp[1+r,i,:] = au.metric(stndata[i],readata_corr[r,i,:])
    met_prcp[4,i,:] = au.metric(stndata[i],readata_merge[i])
del stndata,readata_down,readata_corr,readata_merge
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:390: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /Users/localuser/Github/PyGMET/auxiliary.py:150: RuntimeWarning: Mean of empty slice
#   metout[1] = np.nanmean(pre - obs)  # ME
# ...

# %%
plt.figure(figsize=[14,10])
plt.subplot(221)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_prcp[0,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: downscaled data')

plt.subplot(222)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_prcp[0,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,8])
plt.title('RMSE: downscaled data')

plt.subplot(223)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_prcp[1,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: corrected data')

plt.subplot(224)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_prcp[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,8])
plt.title('RMSE: corrected data')
# Out:
# Text(0.5, 1.0, 'RMSE: corrected data')

# %%
for i in range(5):
    print(np.nanmean(met_prcp[i],axis=0))
# Out:
# [0.53537484 0.26205892 2.49005602 6.31439275]
# [ 0.71711579 -0.17420667  1.70860973  4.7936899 ]
# [ 0.70912098 -0.13936367  1.75805325  4.87115472]
# [ 0.71159044 -0.12570594  1.77838134  4.85933111]
# [ 0.72367185 -0.21742603  1.69461923  4.74440209]

# %%
file1='/Users/localuser/Downloads/stndata_whole.npz'
file2='/Users/localuser/Research/Test/JRA55_downto_stn.npz'
file3='/Users/localuser/Research/Test/mergecorr_tmean_BMA.npz'
d1=np.load(file1)
d2=np.load(file2)
d3=np.load(file3)
stn_lle=d1['stn_lle']
stndata=d1['tmean_stn']
readata_down=d2['tmean_readown']
readata_corr=d3['reacorr_stn']
readata_merge=d3['reamerge_stn']
nstn,ntimes=np.shape(stndata)
met_tmean=np.zeros([5,nstn,4])
for i in range(nstn):
    met_tmean[0,i,:] = au.metric(stndata[i],readata_down[i])
    for r in range(3):
        met_tmean[1+r,i,:] = au.metric(stndata[i],readata_corr[r,i,:])
    met_tmean[4,i,:] = au.metric(stndata[i],readata_merge[i])

# %%
plt.figure(figsize=[14,10])
plt.subplot(221)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_tmean[0,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: downscaled data')

plt.subplot(222)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_tmean[0,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.title('RMSE: downscaled data')

plt.subplot(223)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_tmean[1,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: corrected data')

plt.subplot(224)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_tmean[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.title('RMSE: corrected data')
# Out:
# Text(0.5, 1.0, 'RMSE: corrected data')

# %%
for i in range(5):
    print(np.nanmean(met_tmean[i],axis=0))
# Out:
# [0.93131172 0.44565235 2.0280817  2.59253319]
# [0.95390596 0.0072775  1.43167873 1.86152229]
# [0.9531767  0.00611077 1.43845758 1.87267983]
# [0.95243637 0.00343027 1.45267127 1.88771199]
# [0.95387736 0.0063068  1.42311787 1.85348683]

# %%
file1='/Users/localuser/Downloads/stndata_whole.npz'
file2='/Users/localuser/Research/Test/ERA5_downto_stn.npz'
file3='/Users/localuser/Research/Test/mergecorr_trange_BMA.npz'
d1=np.load(file1)
d2=np.load(file2)
d3=np.load(file3)
stn_lle=d1['stn_lle']
stndata=d1['trange_stn']
readata_down=d2['trange_readown']
readata_corr=d3['reacorr_stn']
readata_merge=d3['reamerge_stn']
nstn,ntimes=np.shape(stndata)
met_trange=np.zeros([5,nstn,4])
for i in range(nstn):
    met_trange[0,i,:] = au.metric(stndata[i],readata_down[i])
    for r in range(3):
        met_trange[1+r,i,:] = au.metric(stndata[i],readata_corr[r,i,:])
    met_trange[4,i,:] = au.metric(stndata[i],readata_merge[i])

# %%
plt.figure(figsize=[14,10])
plt.subplot(221)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_trange[0,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: downscaled data')

plt.subplot(222)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_trange[0,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.title('RMSE: downscaled data')

plt.subplot(223)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_trange[1,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: corrected data')

plt.subplot(224)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_trange[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.title('RMSE: corrected data')
# Out:
# Text(0.5, 1.0, 'RMSE: corrected data')

# %%
for i in range(5):
    print(np.nanmean(met_prcp[i],axis=0))
# Out:
# [ 0.66309181 -2.77792273  3.73641467  4.50729261]
# [0.75558377 0.00402423 2.45591684 3.16678333]
# [0.75158845 0.021099   2.49609959 3.21397457]
# [0.74154005 0.03895172 2.56515831 3.29929942]
# [0.75699575 0.01854413 2.45493013 3.16221866]

# %%
# difference between megrge and ERA5
plt.figure(figsize=[14,14])
plt.subplot(321)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_prcp[4,:,0]-met_prcp[2,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.05,0.05])
plt.title('prcp CC: BMA - MERRA2')

plt.subplot(322)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_prcp[4,:,3]-met_prcp[2,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.05,0.05])
plt.title('prcp RMSE: BMA - MERRA2')

plt.subplot(323)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_tmean[4,:,0]-met_tmean[2,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.05,0.05])
plt.title('tmean CC: BMA - MERRA2')

plt.subplot(324)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_tmean[4,:,3]-met_tmean[2,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.05,0.05])
plt.title('tmean RMSE: BMA - MERRA2')

plt.subplot(325)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_trange[4,:,0]-met_trange[2,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.05,0.05])
plt.title('trange CC: BMA - MERRA2')

plt.subplot(326)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_trange[4,:,3]-met_trange[2,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.05,0.05])
plt.title('trange RMSE: BMA - MERRA2')
# Out:
# Text(0.5, 1.0, 'trange RMSE: BMA - ERA5')

# %%
# evaluate regression estimates
file1='/Users/localuser/Downloads/stndata_whole.npz'
file2='/Users/localuser/GMET/merge/daily_regression_stn.npz'
d1=np.load(file1)
d2=np.load(file2)
stndata=d1['prcp_stn']
regdata=d2['prcp']
nstn,ntimes=np.shape(stndata)
met_prcp=np.zeros([3,nstn,4])
for i in range(nstn):
    met[0,i,:] = au.metric(stndata[i],regdata[i])
stndata=d1['tmean_stn']
regdata=d2['tmean']
for i in range(nstn):
    met[1,i,:] = au.metric(stndata[i],regdata[i])
stndata=d1['trange_stn']
regdata=d2['trange']
for i in range(nstn):
    met[2,i,:] = au.metric(stndata[i],regdata[i])

# %%
plt.figure(figsize=[14,14])
plt.subplot(321)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met[0,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: prcp')

plt.subplot(322)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met[0,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.title('RMSE: prcp')

plt.subplot(323)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met[1,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: tmean')

plt.subplot(324)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.title('RMSE: tmean')

plt.subplot(325)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met[2,:,0],cmap='jet')
plt.colorbar()
plt.clim([0,1])
plt.title('CC: trange')

plt.subplot(326)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met[2,:,3],cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.title('RMSE: trange')
# Out:
# Text(0.5, 1.0, 'RMSE: trange')

# %%
for i in range(3):
    print(np.nanmean(met[i],axis=0))
# Out:
# [0.75061696 0.06594782 1.68350194 4.49071712]
# [ 0.95874781 -0.00753157  1.28792933  1.68811613]
# [ 0.78417763 -0.03856212  2.24325129  2.89873644]

# %%
# difference between regression and merged prcp, tmean, trange
plt.figure(figsize=[14,14])
plt.subplot(321)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_prcp[4,:,0]-met[0,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.1,0.1])
plt.title('prcp CC difference: BMA - regression')

plt.subplot(322)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_prcp[4,:,3]-met[0,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.2,0.2])
plt.title('prcp RMSE difference: BMA - regression')

plt.subplot(323)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_tmean[4,:,0]-met[1,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.1,0.1])
plt.title('Tmean CC difference: BMA - regression')

plt.subplot(324)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_tmean[4,:,3]-met[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.2,0.2])
plt.title('Tmean RMSE difference: BMA - regression')

plt.subplot(325)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_trange[4,:,0]-met[2,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.1,0.1])
plt.title('Trange CC difference: BMA - regression')

plt.subplot(326)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_trange[4,:,3]-met[2,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.2,0.2])
plt.title('Trange RMSE difference: BMA - regression')
# Out:
# Text(0.5, 1.0, 'Trange RMSE difference: BMA - regression')

# %%
# optimal Interpolation
file1='/Users/localuser/Downloads/stndata_whole.npz'
d1=np.load(file1)
stndata=d1['prcp_stn']

file2='/Users/localuser/GMET/merge/OImerge_stn_prcp.npz'
d2=np.load(file2)
oidata=d2['oimerge_stn']
nstn,ntimes=np.shape(stndata)
met_oi=np.zeros([3,nstn,4])
for i in range(nstn):
    met_oi[0,i,:] = au.metric(stndata[i],oidata[i])
    
    
stndata=d1['tmean_stn']
file2='/Users/localuser/GMET/merge/OImerge_stn_tmean.npz'
d2=np.load(file2)
oidata=d2['oimerge_stn']
for i in range(nstn):
    met_oi[1,i,:] = au.metric(stndata[i],oidata[i])
    
stndata=d1['trange_stn']
file2='/Users/localuser/GMET/merge/OImerge_stn_trange.npz'
d2=np.load(file2)
oidata=d2['oimerge_stn']
for i in range(nstn):
    met_oi[2,i,:] = au.metric(stndata[i],oidata[i])

del stndata, oidata
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:390: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /Users/localuser/Github/PyGMET/auxiliary.py:150: RuntimeWarning: Mean of empty slice
#   metout[1] = np.nanmean(pre - obs)  # ME
# ...

# %%
# difference between OI-merge and regression prcp, tmean, trange
plt.figure(figsize=[14,14])
plt.subplot(321)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_oi[0,:,0]-met[0,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.1,0.1])
plt.title('prcp CC difference: BMA - regression')

plt.subplot(322)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_oi[0,:,3]-met[0,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.2,0.2])
plt.title('prcp RMSE difference: BMA - regression')

plt.subplot(323)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_oi[1,:,0]-met[1,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.1,0.1])
plt.title('Tmean CC difference: BMA - regression')

plt.subplot(324)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_oi[1,:,3]-met[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.2,0.2])
plt.title('Tmean RMSE difference: BMA - regression')

plt.subplot(325)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_oi[2,:,0]-met[2,:,0],cmap='jet')
plt.colorbar()
plt.clim([-0.1,0.1])
plt.title('Trange CC difference: BMA - regression')

plt.subplot(326)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_oi[2,:,3]-met[2,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.2,0.2])
plt.title('Trange RMSE difference: BMA - regression')
# Out:
# Text(0.5, 1.0, 'Trange RMSE difference: BMA - regression')

# %%
import numpy as np
import auxiliary as au
file1='/Users/localuser/Downloads/stndata_whole.npz'
file2='/Users/localuser/GMET/merge/daily_regression_stn.npz'
file3='/Users/localuser/Research/Test/mergecorr_prcp_RMSE.npz'
# file4='/Users/localuser/GMET/merge/OImerge_stn_prcp.npz'
file4='/Users/localuser/GMET/merge/OImerge_stn_prcp_neargrid.npz'
d1=np.load(file1)
d2=np.load(file2)
d3=np.load(file3)
d4=np.load(file4)
# print(d1.files,d2.files,d3.files,d4.files)
trange1=d1['prcp_stn']
trange2=d2['prcp']
trange3=d3['reamerge_stn']
trange4=d4['oimerge_stn']
nstn,ntimes=np.shape(trange1)
met=np.zeros([3,nstn,4])
for i in range(nstn):
    met[0,i,:] = au.metric(trange1[i],trange2[i])
    met[1,i,:] = au.metric(trange1[i],trange3[i])
    met[2,i,:] = au.metric(trange1[i],trange4[i])
for i in range(3):
    print(np.nanmean(met[i],axis=0))
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:390: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /Users/localuser/Github/PyGMET/auxiliary.py:150: RuntimeWarning: Mean of empty slice
#   metout[1] = np.nanmean(pre - obs)  # ME
# ...

# %%
# Out:
# array([[            nan,             nan,             nan, ...,
#          1.66248894e+01, -8.15143108e-01,  1.52405584e-02],
#        [            nan,             nan,             nan, ...,
#          8.15651417e+00,  5.51075077e+00, -1.27327675e-02],
#        [            nan,             nan,             nan, ...,
#          7.33805275e+00,  2.45954967e+00, -4.05833460e-02],
#        ...,
#        [            nan,             nan,             nan, ...,
#          7.11466503e+00,  1.97979505e-03,  8.26316547e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [            nan,             nan,             nan, ...,
#          2.16501737e+00, -2.18329467e-02, -1.21851885e+00]])

# %%
# trange33=d3['reacorr_stn']
file5='/Users/localuser/Research/Test/ERA5_downto_stn.npz'
d5=np.load(file5)
trange5=d5['prcp_readown']

file5='/Users/localuser/Research/Test/ERA5_downto_stn.npz'
d5=np.load(file5)
trange5=d5['prcp_readown']

# %%
for i in range(3):
    print(met[i,12300])
# Out:
# [0.74768394 0.07042189 0.63169003 1.61088865]
# [0.67743479 0.06466469 0.68648279 1.82761903]
# [0.80352724 0.02669809 0.57030834 1.44203232]

# %%
# plot figure for a specific station
inum=12300
plt.figure(figsize=[15,15])
plt.subplot(321)
plt.plot(trange1[inum,366:730])
plt.plot(trange2[inum,366:730])
plt.ylim([0,30])
plt.legend(['Station','Station-based regression'],loc='upper right')
met=au.metric(trange1[inum,366:730],trange2[inum,366:730])
met=met[[0,1,3]]
plt.text(0,25,r'CC={0:.2f}, ME={1:.2f}, RMSE={2:.2f}'.format(*[round(meti,3) for meti in met]),fontsize=12)

plt.subplot(322)
plt.plot(trange1[inum,366:730])
plt.plot(trange5[inum,366:730])
plt.ylim([0,30])
plt.legend(['Station','Downscaled ERA5'],loc='upper right')
met=au.metric(trange1[inum,366:730],trange5[inum,366:730])
met=met[[0,1,3]]
plt.text(0,25,r'CC={0:.2f}, ME={1:.2f}, RMSE={2:.2f}'.format(*[round(meti,3) for meti in met]),fontsize=12)


plt.subplot(323)
plt.plot(trange1[inum,366:730])
plt.plot(trange33[0,inum,366:730])
plt.ylim([0,30])
plt.legend(['Station','Corrected ERA5'],loc='upper right')
met=au.metric(trange1[inum,366:730],trange33[0,inum,366:730])
met=met[[0,1,3]]
plt.text(0,25,r'CC={0:.2f}, ME={1:.2f}, RMSE={2:.2f}'.format(*[round(meti,3) for meti in met]),fontsize=12)

plt.subplot(324)
plt.plot(trange1[inum,366:730])
plt.plot(trange3[inum,366:730])
plt.ylim([0,30])
plt.legend(['Station','BMA-Merged reanalysis'],loc='upper right')
met=au.metric(trange1[inum,366:730],trange3[inum,366:730])
met=met[[0,1,3]]
plt.text(0,25,r'CC={0:.2f}, ME={1:.2f}, RMSE={2:.2f}'.format(*[round(meti,3) for meti in met]),fontsize=12)

plt.subplot(325)
plt.plot(trange1[inum,366:730])
plt.plot(trange4[inum,366:730])
plt.ylim([0,30])
plt.legend(['Station','OI-merged final output'],loc='upper right')
met=au.metric(trange1[inum,366:730],trange4[inum,366:730])
met=met[[0,1,3]]
plt.text(0,25,r'CC={0:.2f}, ME={1:.2f}, RMSE={2:.2f}'.format(*[round(meti,3) for meti in met]),fontsize=12)
# Out:
# Text(0, 25, 'CC=0.82, ME=0.02, RMSE=2.03')

# %%
# plot PDF
def epdf(x):
    bins1=np.arange(0.1,1,0.3)
    bins2=np.arange(1,30,0.5)
    bins=np.concatenate((bins1,bins2))
    num=len(bins)-1
    xs = np.zeros(num)
    ys = np.zeros(num)
    for i in range(1,num):
        xs[i] = (bins[i-1]+bins[i])/2
        ys[i] = np.sum((x>bins[i-1]) & (x<=bins[i]))
    return xs, ys

inum=12300
xs,ys=epdf(trange1[inum,366:])
plt.plot(xs,ys)

xs,ys=epdf(trange2[inum,366:])
plt.plot(xs,ys)

xs,ys=epdf(trange5[inum,366:])
plt.plot(xs,ys)

xs,ys=epdf(trange33[0,inum,366:])
plt.plot(xs,ys)

xs,ys=epdf(trange3[inum,366:])
plt.plot(xs,ys)

xs,ys=epdf(trange4[inum,366:])
plt.plot(xs,ys)

plt.legend(['Station','Station regression','Downscaled reanalysis','Corrected reanalysis','BMA merging','OI merging (final)'])

ax = plt.gca()
# ax.set_xscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8c6600dc4131> in <module>
#      13
#      14 inum=12300
# ---> 15 xs,ys=epdf(trange1[inum,366:])
#      16 plt.plot(xs,ys)
#      17
#
# NameError: name 'trange1' is not defined

# %%
ecdf=ECDF(trange1[inum,366:])
plt.plot(ecdf.x,ecdf.y)

ecdf=ECDF(trange2[inum,366:])
plt.plot(ecdf.x,ecdf.y)

ecdf=ECDF(trange5[inum,366:])
plt.plot(ecdf.x,ecdf.y)

ecdf=ECDF(trange33[0,inum,366:])
plt.plot(ecdf.x,ecdf.y)

ecdf=ECDF(trange3[inum,366:])
plt.plot(ecdf.x,ecdf.y)

ecdf=ECDF(trange4[inum,366:])
plt.plot(ecdf.x,ecdf.y)

plt.legend(['Station','Station regression','Downscaled reanalysis','Corrected reanalysis','BMA merging','OI merging (final)'])
plt.xlim([0,30])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ea1cbf7e239d> in <module>
# ----> 1 ecdf=ECDF(trange1[inum,366:])
#       2 plt.plot(ecdf.x,ecdf.y)
#       3
#       4 ecdf=ECDF(trange2[inum,366:])
#       5 plt.plot(ecdf.x,ecdf.y)
#
# NameError: name 'ECDF' is not defined

# %%
import numpy as np
filestn = '/Users/localuser/Downloads/stndata_whole.npz'
filerea = '/Users/localuser/Research/Test/mergecorr_prcp_RMSE.npz'
d1 = np.load(filestn)
d2 = np.load(filerea)
d2.files
# Out:
# ['reamerge_stn', 'reamerge_weight_stn', 'reacorr_stn', 'date_list']

# %%
trange1=d1['tmean_stn']

# %%
stn_lle=d1['stn_lle']
nstn = np.shape(stn_lle)[0]

# %%
file5='/Users/localuser/Research/Test/ERA5_nearneighbor_stn.npz'
d5=np.load(file5)
trange5=d5['tmean_reanear']

# %%
import auxiliary as au
kge1 = np.zeros([nstn,4])
kge2 = np.zeros([nstn,4])
for i in range(nstn):
    kge2[i] = au.kge2012(trange1[i,:]+273.15,trange5[i,:]+273.15)
    kge1[i] = au.kge2012(trange1[i,:],trange5[i,:])

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=[10,10])

plt.subplot(221)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,kge[:,0])
plt.colorbar()
plt.clim([0,1])
plt.title('KGE')

plt.subplot(222)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,kge[:,1])
plt.colorbar()
plt.clim([0,1])
plt.title('r')

plt.subplot(223)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,kge[:,2])
plt.colorbar()
plt.clim([0,2])
plt.title('gamma')

plt.subplot(224)
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,kge[:,3])
plt.colorbar()
plt.clim([0,2])
plt.title('beta')
# Out:
# Text(0.5, 1.0, 'beta')

# %%
z=np.nanmean(trange1,axis=1)
z[abs(z)>1]=2
z[abs(z)<=1]=0
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,z,cmap='jet')
plt.colorbar()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in greater
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in less_equal
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
z=np.nanmean(trange1,axis=1)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=[10,5])

plt.subplot(121)
plt.scatter(z,kge1[:,0])
plt.ylabel('KGE')
plt.xlabel('C')
plt.ylim([-10,1])

plt.subplot(122)
plt.scatter(z+273.15,kge2[:,0])
plt.ylabel('KGE')
plt.xlabel('K')
# Out:
# Text(0.5, 0, 'K')

# %%
import matplotlib
from matplotlib import pyplot as plt
mt=np.nanmean(trange1,axis=1)

cmap=plt.cm.jet
norm = matplotlib.colors.BoundaryNorm(np.arange(-3,10,1), cmap.N)

# plt.scatter(kge2[:,0],kge1[:,0],4,mt,cmap=cmap,norm=norm,edgecolor='none')
plt.scatter(kge2[:,0],kge1[:,0],4,mt,cmap='jet')
plt.plot([-1,1],[-1,1])
cbar = plt.colorbar()
cbar.ax.set_ylabel('Mean temperature (C)', rotation=270)
plt.xlim([-1,1])
plt.ylim([-10,1])
plt.xlabel('KGE in K')
plt.ylabel('KGE in C')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: Mean of empty slice
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0, 0.5, 'KGE in C')

# %%
def ecdf(data, bin=500):
    # data: vector of data
    # bin: number of cdf probability bins

    ecdf_out = np.nan * np.zeros([bin+1, 2], dtype=np.float32) # col-1: probability; col-2: value
    ecdf_out[:, 0] = np.arange(0, 1 + 1/bin, 1/bin)
    data2 = data[~np.isnan(data)]
    if len(data2) > 0:
        ds = np.sort(data)
        prob = np.arange(len(data2)) / (len(data2)+1)
        ecdf_out[:, 1] = np.interp(ecdf_out[:, 0], prob, ds)
    return ecdf_out
ec = ecdf(trange1[4,:],100)
print(ec[0:3,:])
print(ec[-3:,:])
print(np.min(trange1[4,:]))
print(np.max(trange1[4,:]))
# Out:
# [[ 0.        -6.6209087]
#  [ 0.01      -1.25     ]
#  [ 0.02       0.       ]]
# [[ 0.98     22.5     ]
#  [ 0.99     23.603373]
#  [ 1.       28.5     ]]
# -6.6209087
# 28.5

# %%
import numpy as np
import auxiliary as au
# compare the performance of two downscaling methods
file1='/Users/localuser/Downloads/stndata_whole.npz'
file2='/Users/localuser/Research/Test/JRA55_downto_stn.npz'
file3='/Users/localuser/Research/Test/JRA55_downto_stn_nearest.npz'
d1=np.load(file1)
d2=np.load(file2)
d3=np.load(file3)
stn_lle=d1['stn_lle']
stndata=d1['tmean_stn']
readata_down1=d2['tmean_readown']
readata_down2=d3['tmean_readown']
nstn = np.shape(stndata)[0]
met_down_tmean=np.nan * np.zeros([2,nstn,4])
for i in range(nstn):
    if np.isnan(stndata[i,0]):
        continue
    met_down_tmean[0,i,:]=au.metric(stndata[i,:],readata_down1[i,:])
    met_down_tmean[1,i,:]=au.metric(stndata[i,:],readata_down2[i,:])
del stndata,readata_down1,readata_down2
    
stndata=d1['trange_stn']
readata_down1=d2['trange_readown']
readata_down2=d3['trange_readown']
nstn = np.shape(stndata)[0]
met_down_trange=np.nan * np.zeros([2,nstn,4])
for i in range(nstn):
    if np.isnan(stndata[i,0]):
        continue
    met_down_trange[0,i,:]=au.metric(stndata[i,:],readata_down1[i,:])
    met_down_trange[1,i,:]=au.metric(stndata[i,:],readata_down2[i,:])
del stndata,readata_down1,readata_down2

stndata=d1['prcp_stn']
readata_down1=d2['prcp_readown']
readata_down2=d3['prcp_readown']
nstn = np.shape(stndata)[0]
met_down_prcp=np.nan * np.zeros([2,nstn,4])
for i in range(nstn):
    if np.isnan(stndata[i,0]):
        continue
    met_down_prcp[0,i,:]=au.metric(stndata[i,:],readata_down1[i,:])
    met_down_prcp[1,i,:]=au.metric(stndata[i,:],readata_down2[i,:])
del stndata,readata_down1,readata_down2
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:390: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /Users/localuser/Github/PyGMET/auxiliary.py:150: RuntimeWarning: Mean of empty slice
#   metout[1] = np.nanmean(pre - obs)  # ME
# ...

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=[15,10])
plt.subplot(221)
# difference between GWR and nearest downscaling
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_down_prcp[0,:,3]-met_down_prcp[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.2,0.2])
plt.title('prcp RMSE difference: regression - nearest')

plt.subplot(222)
# difference between GWR and nearest downscaling
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_down_tmean[0,:,3]-met_down_tmean[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.2,0.2])
plt.title('tmean RMSE difference: regression - nearest')

plt.subplot(223)
# difference between GWR and nearest downscaling
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_down_trange[0,:,3]-met_down_trange[1,:,3],cmap='jet')
plt.colorbar()
plt.clim([-0.23,0.2])
plt.title('tmean RMSE difference: regression - nearest')
# Out:
# Text(0.5, 1.0, 'tmean RMSE difference: regression - nearest')

# %%
file='/Users/localuser/GMET/merge/OImerge_stn_prcp-compare.npz'
d=np.load(file)
oimerge_stn=d['oimerge_stn']
oimerge_stn2=d['oimerge_stn2']

# %%
file1='/Users/localuser/Downloads/stndata_whole.npz'
d=np.load(file1)
stndata=d1['prcp_stn']

# %%
met_oi_prcp=np.nan * np.zeros([2,nstn,4])
for i in range(nstn):
    if np.isnan(stndata[i,0]):
        continue
    met_oi_prcp[0,i,:]=au.metric(stndata[i,365:396],oimerge_stn[i,365:396])
    met_oi_prcp[1,i,:]=au.metric(stndata[i,365:396],oimerge_stn2[i,365:396])
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:390: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /Users/localuser/Github/PyGMET/auxiliary.py:150: RuntimeWarning: Mean of empty slice
#   metout[1] = np.nanmean(pre - obs)  # ME
# ...

# %%
print(np.nanmean(met_oi_prcp[0],axis=0))
print(np.nanmean(met_oi_prcp[1],axis=0))
# Out:
# [ 0.86188322 -0.0547136   1.03179263  2.18849066]
# [ 0.90084875 -0.01836693  0.78466017  1.64027168]

# %%
plt.scatter(stn_lle[:,1],stn_lle[:,0],5,met_oi_prcp[1,:,3]-met_oi_prcp[0,:,3],cmap='jet')
plt.colorbar()
plt.clim([-1,1])
